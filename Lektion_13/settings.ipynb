# %% [markdown]
# ## Python Version

# %%
# !python --version
# Out:
# Python 3.7.7

# %%
# !which python
# Out:
# /Users/tinvotan/Projects/dhbw_data_mining/venv/bin/python

# %% [markdown]
# ## Verwendete Python-Module

# %%
# !pip list
# Out:
# Package            Version
# ------------------ ------------
# appnope            0.1.0
# attrs              19.3.0
# backcall           0.1.0
# bleach             3.1.4
# cycler             0.10.0
# decorator          4.4.2
# defusedxml         0.6.0
# entrypoints        0.3
# importlib-metadata 1.7.0
# ipykernel          5.2.0
# ipython            7.13.0
# ipython-genutils   0.2.0
# ipywidgets         7.5.1
# jedi               0.16.0
# Jinja2             2.11.1
# joblib             0.14.1
# jsonschema         3.2.0
# jupyter            1.0.0
# jupyter-client     6.1.2
# jupyter-console    6.1.0
# jupyter-core       4.6.3
# kiwisolver         1.1.0
# MarkupSafe         1.1.1
# matplotlib         3.2.1
# mistune            0.8.4
# nbconvert          5.6.1
# nbformat           5.0.4
# notebook           6.0.3
# numpy              1.18.2
# pandas             1.0.3
# pandocfilters      1.4.2
# parso              0.6.2
# pexpect            4.8.0
# pickleshare        0.7.5
# pip                20.1.1
# prometheus-client  0.7.1
# prompt-toolkit     3.0.5
# ptyprocess         0.6.0
# Pygments           2.6.1
# pyparsing          2.4.6
# pyrsistent         0.16.0
# python-dateutil    2.8.1
# pytz               2019.3
# pyzmq              19.0.0
# qtconsole          4.7.2
# QtPy               1.9.0
# scikit-learn       0.22.2.post1
# scipy              1.4.1
# seaborn            0.10.0
# Send2Trash         1.5.0
# setuptools         46.4.0
# six                1.14.0
# terminado          0.8.3
# testpath           0.4.4
# tornado            6.0.4
# traitlets          4.3.3
# wcwidth            0.1.9
# webencodings       0.5.1
# wheel              0.34.2
# widgetsnbextension 3.5.1
# zipp               3.1.0

# %%
# !tree
# Out:
# .
# ├── Pipfile
# ├── Pipfile.lock
# ├── README.md
# ├── UH-BA-Info-Sem6-Data_Mining.key
# ├── UH-BA-Info-Sem6-Data_Mining.pdf
# ├── datasets
# │   └── housing
# │       ├── housing.csv
# │       └── housing.tgz
# ├── images
# │   ├── california.png
# │   └── dhbw.png
# ├── requirements.txt
# ├── settings.ipynb
# ├── venv
# │   ├── bin
# │   │   ├── activate
# │   │   ├── activate.csh
# │   │   ├── activate.fish
# │   │   ├── activate.ps1
# │   │   ├── activate.xsh
# │   │   ├── activate_this.py
# │   │   ├── easy_install
# │   │   ├── easy_install-3.7
# │   │   ├── easy_install3
# │   │   ├── f2py
# │   │   ├── f2py3
# │   │   ├── f2py3.7
# │   │   ├── iptest
# │   │   ├── iptest3
# │   │   ├── ipython
# │   │   ├── ipython3
# │   │   ├── jsonschema
# │   │   ├── jupyter
# │   │   ├── jupyter-bundlerextension
# │   │   ├── jupyter-console
# │   │   ├── jupyter-kernel
# │   │   ├── jupyter-kernelspec
# │   │   ├── jupyter-migrate
# │   │   ├── jupyter-nbconvert
# │   │   ├── jupyter-nbextension
# │   │   ├── jupyter-notebook
# │   │   ├── jupyter-qtconsole
# │   │   ├── jupyter-run
# │   │   ├── jupyter-serverextension
# │   │   ├── jupyter-troubleshoot
# │   │   ├── jupyter-trust
# │   │   ├── pip
# │   │   ├── pip-3.7
# │   │   ├── pip3
# │   │   ├── pip3.7
# │   │   ├── pygmentize
# │   │   ├── python -> /usr/local/opt/python/bin/python3.7
# │   │   ├── python3 -> python
# │   │   ├── python3.7 -> python
# │   │   ├── wheel
# │   │   ├── wheel-3.7
# │   │   └── wheel3
# │   ├── etc
# │   │   └── jupyter
# │   │       └── nbconfig
# │   │           └── notebook.d
# │   │               └── widgetsnbextension.json
# │   ├── lib
# │   │   └── python3.7
# │   │       └── site-packages
# │   │           ├── IPython
# │   │           │   ├── __init__.py
# │   │           │   ├── __main__.py
# │   │           │   ├── __pycache__
# │   │           │   │   ├── __init__.cpython-37.pyc
# │   │           │   │   ├── __main__.cpython-37.pyc
# │   │           │   │   ├── config.cpython-37.pyc
# │   │           │   │   ├── conftest.cpython-37.pyc
# │   │           │   │   ├── consoleapp.cpython-37.pyc
# │   │           │   │   ├── display.cpython-37.pyc
# │   │           │   │   ├── frontend.cpython-37.pyc
# │   │           │   │   ├── html.cpython-37.pyc
# │   │           │   │   ├── nbconvert.cpython-37.pyc
# │   │           │   │   ├── nbformat.cpython-37.pyc
# │   │           │   │   ├── parallel.cpython-37.pyc
# │   │           │   │   ├── paths.cpython-37.pyc
# │   │           │   │   └── qt.cpython-37.pyc
# │   │           │   ├── config.py
# │   │           │   ├── conftest.py
# │   │           │   ├── consoleapp.py
# │   │           │   ├── core
# │   │           │   │   ├── __init__.py
# │   │           │   │   ├── __pycache__
# │   │           │   │   │   ├── __init__.cpython-37.pyc
# │   │           │   │   │   ├── alias.cpython-37.pyc
# │   │           │   │   │   ├── application.cpython-37.pyc
# │   │           │   │   │   ├── async_helpers.cpython-37.pyc
# │   │           │   │   │   ├── autocall.cpython-37.pyc
# │   │           │   │   │   ├── builtin_trap.cpython-37.pyc
# │   │           │   │   │   ├── compilerop.cpython-37.pyc
# │   │           │   │   │   ├── completer.cpython-37.pyc
# │   │           │   │   │   ├── completerlib.cpython-37.pyc
# │   │           │   │   │   ├── crashhandler.cpython-37.pyc
# │   │           │   │   │   ├── debugger.cpython-37.pyc
# │   │           │   │   │   ├── display.cpython-37.pyc
# │   │           │   │   │   ├── display_trap.cpython-37.pyc
# │   │           │   │   │   ├── displayhook.cpython-37.pyc
# │   │           │   │   │   ├── displaypub.cpython-37.pyc
# │   │           │   │   │   ├── error.cpython-37.pyc
# │   │           │   │   │   ├── events.cpython-37.pyc
# │   │           │   │   │   ├── excolors.cpython-37.pyc
# │   │           │   │   │   ├── extensions.cpython-37.pyc
# │   │           │   │   │   ├── formatters.cpython-37.pyc
# │   │           │   │   │   ├── getipython.cpython-37.pyc
# │   │           │   │   │   ├── history.cpython-37.pyc
# │   │           │   │   │   ├── historyapp.cpython-37.pyc
# │   │           │   │   │   ├── hooks.cpython-37.pyc
# │   │           │   │   │   ├── inputsplitter.cpython-37.pyc
# │   │           │   │   │   ├── inputtransformer.cpython-37.pyc
# │   │           │   │   │   ├── inputtransformer2.cpython-37.pyc
# │   │           │   │   │   ├── interactiveshell.cpython-37.pyc
# │   │           │   │   │   ├── latex_symbols.cpython-37.pyc
# │   │           │   │   │   ├── logger.cpython-37.pyc
# │   │           │   │   │   ├── macro.cpython-37.pyc
# │   │           │   │   │   ├── magic.cpython-37.pyc
# │   │           │   │   │   ├── magic_arguments.cpython-37.pyc
# │   │           │   │   │   ├── oinspect.cpython-37.pyc
# │   │           │   │   │   ├── page.cpython-37.pyc
# │   │           │   │   │   ├── payload.cpython-37.pyc
# │   │           │   │   │   ├── payloadpage.cpython-37.pyc
# │   │           │   │   │   ├── prefilter.cpython-37.pyc
# │   │           │   │   │   ├── profileapp.cpython-37.pyc
# │   │           │   │   │   ├── profiledir.cpython-37.pyc
# │   │           │   │   │   ├── prompts.cpython-37.pyc
# │   │           │   │   │   ├── pylabtools.cpython-37.pyc
# │   │           │   │   │   ├── release.cpython-37.pyc
# │   │           │   │   │   ├── shellapp.cpython-37.pyc
# │   │           │   │   │   ├── splitinput.cpython-37.pyc
# │   │           │   │   │   ├── ultratb.cpython-37.pyc
# │   │           │   │   │   └── usage.cpython-37.pyc
# │   │           │   │   ├── alias.py
# │   │           │   │   ├── application.py
# │   │           │   │   ├── async_helpers.py
# │   │           │   │   ├── autocall.py
# │   │           │   │   ├── builtin_trap.py
# │   │           │   │   ├── compilerop.py
# │   │           │   │   ├── completer.py
# │   │           │   │   ├── completerlib.py
# │   │           │   │   ├── crashhandler.py
# │   │           │   │   ├── debugger.py
# │   │           │   │   ├── display.py
# │   │           │   │   ├── display_trap.py
# │   │           │   │   ├── displayhook.py
# │   │           │   │   ├── displaypub.py
# │   │           │   │   ├── error.py
# │   │           │   │   ├── events.py
# │   │           │   │   ├── excolors.py
# │   │           │   │   ├── extensions.py
# │   │           │   │   ├── formatters.py
# │   │           │   │   ├── getipython.py
# │   │           │   │   ├── history.py
# │   │           │   │   ├── historyapp.py
# │   │           │   │   ├── hooks.py
# │   │           │   │   ├── inputsplitter.py
# │   │           │   │   ├── inputtransformer.py
# │   │           │   │   ├── inputtransformer2.py
# │   │           │   │   ├── interactiveshell.py
# │   │           │   │   ├── latex_symbols.py
# │   │           │   │   ├── logger.py
# │   │           │   │   ├── macro.py
# │   │           │   │   ├── magic.py
# │   │           │   │   ├── magic_arguments.py
# │   │           │   │   ├── magics
# │   │           │   │   │   ├── __init__.py
# │   │           │   │   │   ├── __pycache__
# │   │           │   │   │   │   ├── __init__.cpython-37.pyc
# │   │           │   │   │   │   ├── auto.cpython-37.pyc
# │   │           │   │   │   │   ├── basic.cpython-37.pyc
# │   │           │   │   │   │   ├── code.cpython-37.pyc
# │   │           │   │   │   │   ├── config.cpython-37.pyc
# │   │           │   │   │   │   ├── display.cpython-37.pyc
# │   │           │   │   │   │   ├── execution.cpython-37.pyc
# │   │           │   │   │   │   ├── extension.cpython-37.pyc
# │   │           │   │   │   │   ├── history.cpython-37.pyc
# │   │           │   │   │   │   ├── logging.cpython-37.pyc
# │   │           │   │   │   │   ├── namespace.cpython-37.pyc
# │   │           │   │   │   │   ├── osm.cpython-37.pyc
# │   │           │   │   │   │   ├── packaging.cpython-37.pyc
# │   │           │   │   │   │   ├── pylab.cpython-37.pyc
# │   │           │   │   │   │   └── script.cpython-37.pyc
# │   │           │   │   │   ├── auto.py
# │   │           │   │   │   ├── basic.py
# │   │           │   │   │   ├── code.py
# │   │           │   │   │   ├── config.py
# │   │           │   │   │   ├── display.py
# │   │           │   │   │   ├── execution.py
# │   │           │   │   │   ├── extension.py
# │   │           │   │   │   ├── history.py
# │   │           │   │   │   ├── logging.py
# │   │           │   │   │   ├── namespace.py
# │   │           │   │   │   ├── osm.py
# │   │           │   │   │   ├── packaging.py
# │   │           │   │   │   ├── pylab.py
# │   │           │   │   │   └── script.py
# │   │           │   │   ├── oinspect.py
# │   │           │   │   ├── page.py
# │   │           │   │   ├── payload.py
# │   │           │   │   ├── payloadpage.py
# │   │           │   │   ├── prefilter.py
# │   │           │   │   ├── profile
# │   │           │   │   │   └── README_STARTUP
# │   │           │   │   ├── profileapp.py
# │   │           │   │   ├── profiledir.py
# │   │           │   │   ├── prompts.py
# │   │           │   │   ├── pylabtools.py
# │   │           │   │   ├── release.py
# │   │           │   │   ├── shellapp.py
# │   │           │   │   ├── splitinput.py
# │   │           │   │   ├── tests
# │   │           │   │   │   ├── 2x2.jpg
# │   │           │   │   │   ├── 2x2.png
# │   │           │   │   │   ├── __init__.py
# │   │           │   │   │   ├── __pycache__
# │   │           │   │   │   │   ├── __init__.cpython-37.pyc
# │   │           │   │   │   │   ├── bad_all.cpython-37.pyc
# │   │           │   │   │   │   ├── nonascii.cpython-37.pyc
# │   │           │   │   │   │   ├── nonascii2.cpython-37.pyc
# │   │           │   │   │   │   ├── print_argv.cpython-37.pyc
# │   │           │   │   │   │   ├── refbug.cpython-37.pyc
# │   │           │   │   │   │   ├── simpleerr.cpython-37.pyc
# │   │           │   │   │   │   ├── tclass.cpython-37.pyc
# │   │           │   │   │   │   ├── test_alias.cpython-37.pyc
# │   │           │   │   │   │   ├── test_application.cpython-37.pyc
# │   │           │   │   │   │   ├── test_async_helpers.cpython-37.pyc
# │   │           │   │   │   │   ├── test_autocall.cpython-37.pyc
# │   │           │   │   │   │   ├── test_compilerop.cpython-37.pyc
# │   │           │   │   │   │   ├── test_completer.cpython-37.pyc
# │   │           │   │   │   │   ├── test_completerlib.cpython-37.pyc
# │   │           │   │   │   │   ├── test_debugger.cpython-37.pyc
# │   │           │   │   │   │   ├── test_display.cpython-37.pyc
# │   │           │   │   │   │   ├── test_displayhook.cpython-37.pyc
# │   │           │   │   │   │   ├── test_events.cpython-37.pyc
# │   │           │   │   │   │   ├── test_extension.cpython-37.pyc
# │   │           │   │   │   │   ├── test_formatters.cpython-37.pyc
# │   │           │   │   │   │   ├── test_handlers.cpython-37.pyc
# │   │           │   │   │   │   ├── test_history.cpython-37.pyc
# │   │           │   │   │   │   ├── test_hooks.cpython-37.pyc
# │   │           │   │   │   │   ├── test_imports.cpython-37.pyc
# │   │           │   │   │   │   ├── test_inputsplitter.cpython-37.pyc
# │   │           │   │   │   │   ├── test_inputtransformer.cpython-37.pyc
# │   │           │   │   │   │   ├── test_inputtransformer2.cpython-37.pyc
# │   │           │   │   │   │   ├── test_inputtransformer2_line.cpython-37.pyc
# │   │           │   │   │   │   ├── test_interactiveshell.cpython-37.pyc
# │   │           │   │   │   │   ├── test_iplib.cpython-37.pyc
# │   │           │   │   │   │   ├── test_logger.cpython-37.pyc
# │   │           │   │   │   │   ├── test_magic.cpython-37.pyc
# │   │           │   │   │   │   ├── test_magic_arguments.cpython-37.pyc
# │   │           │   │   │   │   ├── test_magic_terminal.cpython-37.pyc
# │   │           │   │   │   │   ├── test_oinspect.cpython-37.pyc
# │   │           │   │   │   │   ├── test_page.cpython-37.pyc
# │   │           │   │   │   │   ├── test_paths.cpython-37.pyc
# │   │           │   │   │   │   ├── test_prefilter.cpython-37.pyc
# │   │           │   │   │   │   ├── test_profile.cpython-37.pyc
# │   │           │   │   │   │   ├── test_prompts.cpython-37.pyc
# │   │           │   │   │   │   ├── test_pylabtools.cpython-37.pyc
# │   │           │   │   │   │   ├── test_run.cpython-37.pyc
# │   │           │   │   │   │   ├── test_shellapp.cpython-37.pyc
# │   │           │   │   │   │   ├── test_splitinput.cpython-37.pyc
# │   │           │   │   │   │   └── test_ultratb.cpython-37.pyc
# │   │           │   │   │   ├── bad_all.py
# │   │           │   │   │   ├── daft_extension
# │   │           │   │   │   │   ├── __pycache__
# │   │           │   │   │   │   │   └── daft_extension.cpython-37.pyc
# │   │           │   │   │   │   └── daft_extension.py
# │   │           │   │   │   ├── nonascii.py
# │   │           │   │   │   ├── nonascii2.py
# │   │           │   │   │   ├── print_argv.py
# │   │           │   │   │   ├── refbug.py
# │   │           │   │   │   ├── simpleerr.py
# │   │           │   │   │   ├── tclass.py
# │   │           │   │   │   ├── test_alias.py
# │   │           │   │   │   ├── test_application.py
# │   │           │   │   │   ├── test_async_helpers.py
# │   │           │   │   │   ├── test_autocall.py
# │   │           │   │   │   ├── test_compilerop.py
# │   │           │   │   │   ├── test_completer.py
# │   │           │   │   │   ├── test_completerlib.py
# │   │           │   │   │   ├── test_debugger.py
# │   │           │   │   │   ├── test_display.py
# │   │           │   │   │   ├── test_displayhook.py
# │   │           │   │   │   ├── test_events.py
# │   │           │   │   │   ├── test_extension.py
# │   │           │   │   │   ├── test_formatters.py
# │   │           │   │   │   ├── test_handlers.py
# │   │           │   │   │   ├── test_history.py
# │   │           │   │   │   ├── test_hooks.py
# │   │           │   │   │   ├── test_imports.py
# │   │           │   │   │   ├── test_inputsplitter.py
# │   │           │   │   │   ├── test_inputtransformer.py
# │   │           │   │   │   ├── test_inputtransformer2.py
# │   │           │   │   │   ├── test_inputtransformer2_line.py
# │   │           │   │   │   ├── test_interactiveshell.py
# │   │           │   │   │   ├── test_iplib.py
# │   │           │   │   │   ├── test_logger.py
# │   │           │   │   │   ├── test_magic.py
# │   │           │   │   │   ├── test_magic_arguments.py
# │   │           │   │   │   ├── test_magic_terminal.py
# │   │           │   │   │   ├── test_oinspect.py
# │   │           │   │   │   ├── test_page.py
# │   │           │   │   │   ├── test_paths.py
# │   │           │   │   │   ├── test_prefilter.py
# │   │           │   │   │   ├── test_profile.py
# │   │           │   │   │   ├── test_prompts.py
# │   │           │   │   │   ├── test_pylabtools.py
# │   │           │   │   │   ├── test_run.py
# │   │           │   │   │   ├── test_shellapp.py
# │   │           │   │   │   ├── test_splitinput.py
# │   │           │   │   │   └── test_ultratb.py
# │   │           │   │   ├── ultratb.py
# │   │           │   │   └── usage.py
# │   │           │   ├── display.py
# │   │           │   ├── extensions
# │   │           │   │   ├── __init__.py
# │   │           │   │   ├── __pycache__
# │   │           │   │   │   ├── __init__.cpython-37.pyc
# │   │           │   │   │   ├── autoreload.cpython-37.pyc
# │   │           │   │   │   ├── cythonmagic.cpython-37.pyc
# │   │           │   │   │   ├── rmagic.cpython-37.pyc
# │   │           │   │   │   ├── storemagic.cpython-37.pyc
# │   │           │   │   │   └── sympyprinting.cpython-37.pyc
# │   │           │   │   ├── autoreload.py
# │   │           │   │   ├── cythonmagic.py
# │   │           │   │   ├── rmagic.py
# │   │           │   │   ├── storemagic.py
# │   │           │   │   ├── sympyprinting.py
# │   │           │   │   └── tests
# │   │           │   │       ├── __init__.py
# │   │           │   │       ├── __pycache__
# │   │           │   │       │   ├── __init__.cpython-37.pyc
# │   │           │   │       │   ├── test_autoreload.cpython-37.pyc
# │   │           │   │       │   └── test_storemagic.cpython-37.pyc
# │   │           │   │       ├── test_autoreload.py
# │   │           │   │       └── test_storemagic.py
# │   │           │   ├── external
# │   │           │   │   ├── __init__.py
# │   │           │   │   ├── __pycache__
# │   │           │   │   │   ├── __init__.cpython-37.pyc
# │   │           │   │   │   ├── mathjax.cpython-37.pyc
# │   │           │   │   │   ├── qt_for_kernel.cpython-37.pyc
# │   │           │   │   │   └── qt_loaders.cpython-37.pyc
# │   │           │   │   ├── decorators
# │   │           │   │   │   ├── __init__.py
# │   │           │   │   │   ├── __pycache__
# │   │           │   │   │   │   ├── __init__.cpython-37.pyc
# │   │           │   │   │   │   ├── _decorators.cpython-37.pyc
# │   │           │   │   │   │   └── _numpy_testing_noseclasses.cpython-37.pyc
# │   │           │   │   │   ├── _decorators.py
# │   │           │   │   │   └── _numpy_testing_noseclasses.py
# │   │           │   │   ├── mathjax.py
# │   │           │   │   ├── qt_for_kernel.py
# │   │           │   │   └── qt_loaders.py
# │   │           │   ├── frontend.py
# │   │           │   ├── html.py
# │   │           │   ├── kernel
# │   │           │   │   ├── __init__.py
# │   │           │   │   ├── __main__.py
# │   │           │   │   ├── __pycache__
# │   │           │   │   │   ├── __init__.cpython-37.pyc
# │   │           │   │   │   ├── __main__.cpython-37.pyc
# │   │           │   │   │   ├── adapter.cpython-37.pyc
# │   │           │   │   │   ├── channels.cpython-37.pyc
# │   │           │   │   │   ├── channelsabc.cpython-37.pyc
# │   │           │   │   │   ├── client.cpython-37.pyc
# │   │           │   │   │   ├── clientabc.cpython-37.pyc
# │   │           │   │   │   ├── connect.cpython-37.pyc
# │   │           │   │   │   ├── kernelspec.cpython-37.pyc
# │   │           │   │   │   ├── kernelspecapp.cpython-37.pyc
# │   │           │   │   │   ├── launcher.cpython-37.pyc
# │   │           │   │   │   ├── manager.cpython-37.pyc
# │   │           │   │   │   ├── managerabc.cpython-37.pyc
# │   │           │   │   │   ├── multikernelmanager.cpython-37.pyc
# │   │           │   │   │   ├── restarter.cpython-37.pyc
# │   │           │   │   │   └── threaded.cpython-37.pyc
# │   │           │   │   ├── adapter.py
# │   │           │   │   ├── channels.py
# │   │           │   │   ├── channelsabc.py
# │   │           │   │   ├── client.py
# │   │           │   │   ├── clientabc.py
# │   │           │   │   ├── connect.py
# │   │           │   │   ├── kernelspec.py
# │   │           │   │   ├── kernelspecapp.py
# │   │           │   │   ├── launcher.py
# │   │           │   │   ├── manager.py
# │   │           │   │   ├── managerabc.py
# │   │           │   │   ├── multikernelmanager.py
# │   │           │   │   ├── restarter.py
# │   │           │   │   └── threaded.py
# │   │           │   ├── lib
# │   │           │   │   ├── __init__.py
# │   │           │   │   ├── __pycache__
# │   │           │   │   │   ├── __init__.cpython-37.pyc
# │   │           │   │   │   ├── backgroundjobs.cpython-37.pyc
# │   │           │   │   │   ├── clipboard.cpython-37.pyc
# │   │           │   │   │   ├── deepreload.cpython-37.pyc
# │   │           │   │   │   ├── demo.cpython-37.pyc
# │   │           │   │   │   ├── display.cpython-37.pyc
# │   │           │   │   │   ├── editorhooks.cpython-37.pyc
# │   │           │   │   │   ├── guisupport.cpython-37.pyc
# │   │           │   │   │   ├── inputhook.cpython-37.pyc
# │   │           │   │   │   ├── inputhookglut.cpython-37.pyc
# │   │           │   │   │   ├── inputhookgtk.cpython-37.pyc
# │   │           │   │   │   ├── inputhookgtk3.cpython-37.pyc
# │   │           │   │   │   ├── inputhookpyglet.cpython-37.pyc
# │   │           │   │   │   ├── inputhookqt4.cpython-37.pyc
# │   │           │   │   │   ├── inputhookwx.cpython-37.pyc
# │   │           │   │   │   ├── kernel.cpython-37.pyc
# │   │           │   │   │   ├── latextools.cpython-37.pyc
# │   │           │   │   │   ├── lexers.cpython-37.pyc
# │   │           │   │   │   ├── pretty.cpython-37.pyc
# │   │           │   │   │   └── security.cpython-37.pyc
# │   │           │   │   ├── backgroundjobs.py
# │   │           │   │   ├── clipboard.py
# │   │           │   │   ├── deepreload.py
# │   │           │   │   ├── demo.py
# │   │           │   │   ├── display.py
# │   │           │   │   ├── editorhooks.py
# │   │           │   │   ├── guisupport.py
# │   │           │   │   ├── inputhook.py
# │   │           │   │   ├── inputhookglut.py
# │   │           │   │   ├── inputhookgtk.py
# │   │           │   │   ├── inputhookgtk3.py
# │   │           │   │   ├── inputhookpyglet.py
# │   │           │   │   ├── inputhookqt4.py
# │   │           │   │   ├── inputhookwx.py
# │   │           │   │   ├── kernel.py
# │   │           │   │   ├── latextools.py
# │   │           │   │   ├── lexers.py
# │   │           │   │   ├── pretty.py
# │   │           │   │   ├── security.py
# │   │           │   │   └── tests
# │   │           │   │       ├── __init__.py
# │   │           │   │       ├── __pycache__
# │   │           │   │       │   ├── __init__.cpython-37.pyc
# │   │           │   │       │   ├── test_backgroundjobs.cpython-37.pyc
# │   │           │   │       │   ├── test_clipboard.cpython-37.pyc
# │   │           │   │       │   ├── test_deepreload.cpython-37.pyc
# │   │           │   │       │   ├── test_display.cpython-37.pyc
# │   │           │   │       │   ├── test_editorhooks.cpython-37.pyc
# │   │           │   │       │   ├── test_imports.cpython-37.pyc
# │   │           │   │       │   ├── test_latextools.cpython-37.pyc
# │   │           │   │       │   ├── test_lexers.cpython-37.pyc
# │   │           │   │       │   ├── test_pretty.cpython-37.pyc
# │   │           │   │       │   └── test_security.cpython-37.pyc
# │   │           │   │       ├── test.wav
# │   │           │   │       ├── test_backgroundjobs.py
# │   │           │   │       ├── test_clipboard.py
# │   │           │   │       ├── test_deepreload.py
# │   │           │   │       ├── test_display.py
# │   │           │   │       ├── test_editorhooks.py
# │   │           │   │       ├── test_imports.py
# │   │           │   │       ├── test_latextools.py
# │   │           │   │       ├── test_lexers.py
# │   │           │   │       ├── test_pretty.py
# │   │           │   │       └── test_security.py
# │   │           │   ├── nbconvert.py
# │   │           │   ├── nbformat.py
# │   │           │   ├── parallel.py
# │   │           │   ├── paths.py
# │   │           │   ├── qt.py
# │   │           │   ├── sphinxext
# │   │           │   │   ├── __init__.py
# │   │           │   │   ├── __pycache__
# │   │           │   │   │   ├── __init__.cpython-37.pyc
# │   │           │   │   │   ├── custom_doctests.cpython-37.pyc
# │   │           │   │   │   ├── ipython_console_highlighting.cpython-37.pyc
# │   │           │   │   │   └── ipython_directive.cpython-37.pyc
# │   │           │   │   ├── custom_doctests.py
# │   │           │   │   ├── ipython_console_highlighting.py
# │   │           │   │   └── ipython_directive.py
# │   │           │   ├── terminal
# │   │           │   │   ├── __init__.py
# │   │           │   │   ├── __pycache__
# │   │           │   │   │   ├── __init__.cpython-37.pyc
# │   │           │   │   │   ├── console.cpython-37.pyc
# │   │           │   │   │   ├── debugger.cpython-37.pyc
# │   │           │   │   │   ├── embed.cpython-37.pyc
# │   │           │   │   │   ├── interactiveshell.cpython-37.pyc
# │   │           │   │   │   ├── ipapp.cpython-37.pyc
# │   │           │   │   │   ├── magics.cpython-37.pyc
# │   │           │   │   │   ├── prompts.cpython-37.pyc
# │   │           │   │   │   ├── ptshell.cpython-37.pyc
# │   │           │   │   │   ├── ptutils.cpython-37.pyc
# │   │           │   │   │   └── shortcuts.cpython-37.pyc
# │   │           │   │   ├── console.py
# │   │           │   │   ├── debugger.py
# │   │           │   │   ├── embed.py
# │   │           │   │   ├── interactiveshell.py
# │   │           │   │   ├── ipapp.py
# │   │           │   │   ├── magics.py
# │   │           │   │   ├── prompts.py
# │   │           │   │   ├── pt_inputhooks
# │   │           │   │   │   ├── __init__.py
# │   │           │   │   │   ├── __pycache__
# │   │           │   │   │   │   ├── __init__.cpython-37.pyc
# │   │           │   │   │   │   ├── asyncio.cpython-37.pyc
# │   │           │   │   │   │   ├── glut.cpython-37.pyc
# │   │           │   │   │   │   ├── gtk.cpython-37.pyc
# │   │           │   │   │   │   ├── gtk3.cpython-37.pyc
# │   │           │   │   │   │   ├── osx.cpython-37.pyc
# │   │           │   │   │   │   ├── pyglet.cpython-37.pyc
# │   │           │   │   │   │   ├── qt.cpython-37.pyc
# │   │           │   │   │   │   ├── tk.cpython-37.pyc
# │   │           │   │   │   │   └── wx.cpython-37.pyc
# │   │           │   │   │   ├── asyncio.py
# │   │           │   │   │   ├── glut.py
# │   │           │   │   │   ├── gtk.py
# │   │           │   │   │   ├── gtk3.py
# │   │           │   │   │   ├── osx.py
# │   │           │   │   │   ├── pyglet.py
# │   │           │   │   │   ├── qt.py
# │   │           │   │   │   ├── tk.py
# │   │           │   │   │   └── wx.py
# │   │           │   │   ├── ptshell.py
# │   │           │   │   ├── ptutils.py
# │   │           │   │   ├── shortcuts.py
# │   │           │   │   └── tests
# │   │           │   │       ├── __init__.py
# │   │           │   │       ├── __pycache__
# │   │           │   │       │   ├── __init__.cpython-37.pyc
# │   │           │   │       │   ├── test_debug_magic.cpython-37.pyc
# │   │           │   │       │   ├── test_embed.cpython-37.pyc
# │   │           │   │       │   ├── test_help.cpython-37.pyc
# │   │           │   │       │   └── test_interactivshell.cpython-37.pyc
# │   │           │   │       ├── test_debug_magic.py
# │   │           │   │       ├── test_embed.py
# │   │           │   │       ├── test_help.py
# │   │           │   │       └── test_interactivshell.py
# │   │           │   ├── testing
# │   │           │   │   ├── __init__.py
# │   │           │   │   ├── __main__.py
# │   │           │   │   ├── __pycache__
# │   │           │   │   │   ├── __init__.cpython-37.pyc
# │   │           │   │   │   ├── __main__.cpython-37.pyc
# │   │           │   │   │   ├── decorators.cpython-37.pyc
# │   │           │   │   │   ├── globalipapp.cpython-37.pyc
# │   │           │   │   │   ├── iptest.cpython-37.pyc
# │   │           │   │   │   ├── iptestcontroller.cpython-37.pyc
# │   │           │   │   │   ├── ipunittest.cpython-37.pyc
# │   │           │   │   │   ├── skipdoctest.cpython-37.pyc
# │   │           │   │   │   └── tools.cpython-37.pyc
# │   │           │   │   ├── decorators.py
# │   │           │   │   ├── globalipapp.py
# │   │           │   │   ├── iptest.py
# │   │           │   │   ├── iptestcontroller.py
# │   │           │   │   ├── ipunittest.py
# │   │           │   │   ├── plugin
# │   │           │   │   │   ├── README.txt
# │   │           │   │   │   ├── __init__.py
# │   │           │   │   │   ├── __pycache__
# │   │           │   │   │   │   ├── __init__.cpython-37.pyc
# │   │           │   │   │   │   ├── dtexample.cpython-37.pyc
# │   │           │   │   │   │   ├── ipdoctest.cpython-37.pyc
# │   │           │   │   │   │   ├── iptest.cpython-37.pyc
# │   │           │   │   │   │   ├── setup.cpython-37.pyc
# │   │           │   │   │   │   ├── show_refs.cpython-37.pyc
# │   │           │   │   │   │   ├── simple.cpython-37.pyc
# │   │           │   │   │   │   ├── simplevars.cpython-37.pyc
# │   │           │   │   │   │   ├── test_ipdoctest.cpython-37.pyc
# │   │           │   │   │   │   └── test_refs.cpython-37.pyc
# │   │           │   │   │   ├── dtexample.py
# │   │           │   │   │   ├── ipdoctest.py
# │   │           │   │   │   ├── iptest.py
# │   │           │   │   │   ├── setup.py
# │   │           │   │   │   ├── show_refs.py
# │   │           │   │   │   ├── simple.py
# │   │           │   │   │   ├── simplevars.py
# │   │           │   │   │   ├── test_combo.txt
# │   │           │   │   │   ├── test_example.txt
# │   │           │   │   │   ├── test_exampleip.txt
# │   │           │   │   │   ├── test_ipdoctest.py
# │   │           │   │   │   └── test_refs.py
# │   │           │   │   ├── skipdoctest.py
# │   │           │   │   ├── tests
# │   │           │   │   │   ├── __init__.py
# │   │           │   │   │   ├── __pycache__
# │   │           │   │   │   │   ├── __init__.cpython-37.pyc
# │   │           │   │   │   │   ├── test_decorators.cpython-37.pyc
# │   │           │   │   │   │   ├── test_ipunittest.cpython-37.pyc
# │   │           │   │   │   │   └── test_tools.cpython-37.pyc
# │   │           │   │   │   ├── test_decorators.py
# │   │           │   │   │   ├── test_ipunittest.py
# │   │           │   │   │   └── test_tools.py
# │   │           │   │   └── tools.py
# │   │           │   └── utils
# │   │           │       ├── PyColorize.py
# │   │           │       ├── __init__.py
# │   │           │       ├── __pycache__
# │   │           │       │   ├── PyColorize.cpython-37.pyc
# │   │           │       │   ├── __init__.cpython-37.pyc
# │   │           │       │   ├── _process_cli.cpython-37.pyc
# │   │           │       │   ├── _process_common.cpython-37.pyc
# │   │           │       │   ├── _process_posix.cpython-37.pyc
# │   │           │       │   ├── _process_win32.cpython-37.pyc
# │   │           │       │   ├── _process_win32_controller.cpython-37.pyc
# │   │           │       │   ├── _sysinfo.cpython-37.pyc
# │   │           │       │   ├── capture.cpython-37.pyc
# │   │           │       │   ├── colorable.cpython-37.pyc
# │   │           │       │   ├── coloransi.cpython-37.pyc
# │   │           │       │   ├── contexts.cpython-37.pyc
# │   │           │       │   ├── daemonize.cpython-37.pyc
# │   │           │       │   ├── data.cpython-37.pyc
# │   │           │       │   ├── decorators.cpython-37.pyc
# │   │           │       │   ├── dir2.cpython-37.pyc
# │   │           │       │   ├── encoding.cpython-37.pyc
# │   │           │       │   ├── eventful.cpython-37.pyc
# │   │           │       │   ├── frame.cpython-37.pyc
# │   │           │       │   ├── generics.cpython-37.pyc
# │   │           │       │   ├── importstring.cpython-37.pyc
# │   │           │       │   ├── io.cpython-37.pyc
# │   │           │       │   ├── ipstruct.cpython-37.pyc
# │   │           │       │   ├── jsonutil.cpython-37.pyc
# │   │           │       │   ├── localinterfaces.cpython-37.pyc
# │   │           │       │   ├── log.cpython-37.pyc
# │   │           │       │   ├── module_paths.cpython-37.pyc
# │   │           │       │   ├── openpy.cpython-37.pyc
# │   │           │       │   ├── path.cpython-37.pyc
# │   │           │       │   ├── pickleutil.cpython-37.pyc
# │   │           │       │   ├── process.cpython-37.pyc
# │   │           │       │   ├── py3compat.cpython-37.pyc
# │   │           │       │   ├── sentinel.cpython-37.pyc
# │   │           │       │   ├── shimmodule.cpython-37.pyc
# │   │           │       │   ├── signatures.cpython-37.pyc
# │   │           │       │   ├── strdispatch.cpython-37.pyc
# │   │           │       │   ├── sysinfo.cpython-37.pyc
# │   │           │       │   ├── syspathcontext.cpython-37.pyc
# │   │           │       │   ├── tempdir.cpython-37.pyc
# │   │           │       │   ├── terminal.cpython-37.pyc
# │   │           │       │   ├── text.cpython-37.pyc
# │   │           │       │   ├── timing.cpython-37.pyc
# │   │           │       │   ├── tokenutil.cpython-37.pyc
# │   │           │       │   ├── traitlets.cpython-37.pyc
# │   │           │       │   ├── tz.cpython-37.pyc
# │   │           │       │   ├── ulinecache.cpython-37.pyc
# │   │           │       │   ├── version.cpython-37.pyc
# │   │           │       │   └── wildcard.cpython-37.pyc
# │   │           │       ├── _process_cli.py
# │   │           │       ├── _process_common.py
# │   │           │       ├── _process_posix.py
# │   │           │       ├── _process_win32.py
# │   │           │       ├── _process_win32_controller.py
# │   │           │       ├── _sysinfo.py
# │   │           │       ├── capture.py
# │   │           │       ├── colorable.py
# │   │           │       ├── coloransi.py
# │   │           │       ├── contexts.py
# │   │           │       ├── daemonize.py
# │   │           │       ├── data.py
# │   │           │       ├── decorators.py
# │   │           │       ├── dir2.py
# │   │           │       ├── encoding.py
# │   │           │       ├── eventful.py
# │   │           │       ├── frame.py
# │   │           │       ├── generics.py
# │   │           │       ├── importstring.py
# │   │           │       ├── io.py
# │   │           │       ├── ipstruct.py
# │   │           │       ├── jsonutil.py
# │   │           │       ├── localinterfaces.py
# │   │           │       ├── log.py
# │   │           │       ├── module_paths.py
# │   │           │       ├── openpy.py
# │   │           │       ├── path.py
# │   │           │       ├── pickleutil.py
# │   │           │       ├── process.py
# │   │           │       ├── py3compat.py
# │   │           │       ├── sentinel.py
# │   │           │       ├── shimmodule.py
# │   │           │       ├── signatures.py
# │   │           │       ├── strdispatch.py
# │   │           │       ├── sysinfo.py
# │   │           │       ├── syspathcontext.py
# │   │           │       ├── tempdir.py
# │   │           │       ├── terminal.py
# │   │           │       ├── tests
# │   │           │       │   ├── __init__.py
# │   │           │       │   ├── __pycache__
# │   │           │       │   │   ├── __init__.cpython-37.pyc
# │   │           │       │   │   ├── test_capture.cpython-37.pyc
# │   │           │       │   │   ├── test_decorators.cpython-37.pyc
# │   │           │       │   │   ├── test_dir2.cpython-37.pyc
# │   │           │       │   │   ├── test_imports.cpython-37.pyc
# │   │           │       │   │   ├── test_importstring.cpython-37.pyc
# │   │           │       │   │   ├── test_io.cpython-37.pyc
# │   │           │       │   │   ├── test_module_paths.cpython-37.pyc
# │   │           │       │   │   ├── test_openpy.cpython-37.pyc
# │   │           │       │   │   ├── test_path.cpython-37.pyc
# │   │           │       │   │   ├── test_process.cpython-37.pyc
# │   │           │       │   │   ├── test_pycolorize.cpython-37.pyc
# │   │           │       │   │   ├── test_shimmodule.cpython-37.pyc
# │   │           │       │   │   ├── test_sysinfo.cpython-37.pyc
# │   │           │       │   │   ├── test_tempdir.cpython-37.pyc
# │   │           │       │   │   ├── test_text.cpython-37.pyc
# │   │           │       │   │   ├── test_tokenutil.cpython-37.pyc
# │   │           │       │   │   └── test_wildcard.cpython-37.pyc
# │   │           │       │   ├── test_capture.py
# │   │           │       │   ├── test_decorators.py
# │   │           │       │   ├── test_dir2.py
# │   │           │       │   ├── test_imports.py
# │   │           │       │   ├── test_importstring.py
# │   │           │       │   ├── test_io.py
# │   │           │       │   ├── test_module_paths.py
# │   │           │       │   ├── test_openpy.py
# │   │           │       │   ├── test_path.py
# │   │           │       │   ├── test_process.py
# │   │           │       │   ├── test_pycolorize.py
# │   │           │       │   ├── test_shimmodule.py
# │   │           │       │   ├── test_sysinfo.py
# │   │           │       │   ├── test_tempdir.py
# │   │           │       │   ├── test_text.py
# │   │           │       │   ├── test_tokenutil.py
# │   │           │       │   └── test_wildcard.py
# │   │           │       ├── text.py
# │   │           │       ├── timing.py
# │   │           │       ├── tokenutil.py
# │   │           │       ├── traitlets.py
# │   │           │       ├── tz.py
# │   │           │       ├── ulinecache.py
# │   │           │       ├── version.py
# │   │           │       └── wildcard.py
# │   │           ├── Jinja2-2.11.1.dist-info
# │   │           │   ├── INSTALLER
# │   │           │   ├── LICENSE.rst
# │   │           │   ├── METADATA
# │   │           │   ├── RECORD
# │   │           │   ├── WHEEL
# │   │           │   ├── entry_points.txt
# │   │           │   └── top_level.txt
# │   │           ├── MarkupSafe-1.1.1.dist-info
# │   │           │   ├── INSTALLER
# │   │           │   ├── LICENSE.rst
# │   │           │   ├── METADATA
# │   │           │   ├── RECORD
# │   │           │   ├── WHEEL
# │   │           │   └── top_level.txt
# │   │           ├── Pygments-2.6.1.dist-info
# │   │           │   ├── AUTHORS
# │   │           │   ├── INSTALLER
# │   │           │   ├── LICENSE
# │   │           │   ├── METADATA
# │   │           │   ├── RECORD
# │   │           │   ├── WHEEL
# │   │           │   ├── entry_points.txt
# │   │           │   └── top_level.txt
# │   │           ├── QtPy-1.9.0.dist-info
# │   │           │   ├── AUTHORS.md
# │   │           │   ├── INSTALLER
# │   │           │   ├── LICENSE.txt
# │   │           │   ├── METADATA
# │   │           │   ├── RECORD
# │   │           │   ├── WHEEL
# │   │           │   └── top_level.txt
# │   │           ├── Send2Trash-1.5.0.dist-info
# │   │           │   ├── DESCRIPTION.rst
# │   │           │   ├── INSTALLER
# │   │           │   ├── METADATA
# │   │           │   ├── RECORD
# │   │           │   ├── WHEEL
# │   │           │   ├── metadata.json
# │   │           │   └── top_level.txt
# │   │           ├── __pycache__
# │   │           │   ├── _pyrsistent_version.cpython-37.pyc
# │   │           │   ├── _virtualenv.cpython-37.pyc
# │   │           │   ├── cycler.cpython-37.pyc
# │   │           │   ├── decorator.cpython-37.pyc
# │   │           │   ├── entrypoints.cpython-37.pyc
# │   │           │   ├── ipykernel_launcher.cpython-37.pyc
# │   │           │   ├── jupyter.cpython-37.pyc
# │   │           │   ├── mistune.cpython-37.pyc
# │   │           │   ├── pandocfilters.cpython-37.pyc
# │   │           │   ├── pickleshare.cpython-37.pyc
# │   │           │   ├── pylab.cpython-37.pyc
# │   │           │   ├── pyparsing.cpython-37.pyc
# │   │           │   ├── six.cpython-37.pyc
# │   │           │   └── zipp.cpython-37.pyc
# │   │           ├── _pyrsistent_version.py
# │   │           ├── _virtualenv.pth
# │   │           ├── _virtualenv.py
# │   │           ├── appnope
# │   │           │   ├── __init__.py
# │   │           │   ├── __pycache__
# │   │           │   │   ├── __init__.cpython-37.pyc
# │   │           │   │   ├── _dummy.cpython-37.pyc
# │   │           │   │   └── _nope.cpython-37.pyc
# │   │           │   ├── _dummy.py
# │   │           │   └── _nope.py
# │   │           ├── appnope-0.1.0.dist-info
# │   │           │   ├── DESCRIPTION.rst
# │   │           │   ├── INSTALLER
# │   │           │   ├── METADATA
# │   │           │   ├── RECORD
# │   │           │   ├── WHEEL
# │   │           │   ├── metadata.json
# │   │           │   └── top_level.txt
# │   │           ├── attr
# │   │           │   ├── __init__.py
# │   │           │   ├── __init__.pyi
# │   │           │   ├── __pycache__
# │   │           │   │   ├── __init__.cpython-37.pyc
# │   │           │   │   ├── _compat.cpython-37.pyc
# │   │           │   │   ├── _config.cpython-37.pyc
# │   │           │   │   ├── _funcs.cpython-37.pyc
# │   │           │   │   ├── _make.cpython-37.pyc
# │   │           │   │   ├── _version_info.cpython-37.pyc
# │   │           │   │   ├── converters.cpython-37.pyc
# │   │           │   │   ├── exceptions.cpython-37.pyc
# │   │           │   │   ├── filters.cpython-37.pyc
# │   │           │   │   └── validators.cpython-37.pyc
# │   │           │   ├── _compat.py
# │   │           │   ├── _config.py
# │   │           │   ├── _funcs.py
# │   │           │   ├── _make.py
# │   │           │   ├── _version_info.py
# │   │           │   ├── _version_info.pyi
# │   │           │   ├── converters.py
# │   │           │   ├── converters.pyi
# │   │           │   ├── exceptions.py
# │   │           │   ├── exceptions.pyi
# │   │           │   ├── filters.py
# │   │           │   ├── filters.pyi
# │   │           │   ├── py.typed
# │   │           │   ├── validators.py
# │   │           │   └── validators.pyi
# │   │           ├── attrs-19.3.0.dist-info
# │   │           │   ├── INSTALLER
# │   │           │   ├── LICENSE
# │   │           │   ├── METADATA
# │   │           │   ├── RECORD
# │   │           │   ├── WHEEL
# │   │           │   └── top_level.txt
# │   │           ├── backcall
# │   │           │   ├── __init__.py
# │   │           │   ├── __pycache__
# │   │           │   │   ├── __init__.cpython-37.pyc
# │   │           │   │   ├── _signatures.cpython-37.pyc
# │   │           │   │   └── backcall.cpython-37.pyc
# │   │           │   ├── _signatures.py
# │   │           │   └── backcall.py
# │   │           ├── backcall-0.1.0.dist-info
# │   │           │   ├── INSTALLER
# │   │           │   ├── METADATA
# │   │           │   ├── RECORD
# │   │           │   ├── WHEEL
# │   │           │   └── top_level.txt
# │   │           ├── bleach
# │   │           │   ├── __init__.py
# │   │           │   ├── __pycache__
# │   │           │   │   ├── __init__.cpython-37.pyc
# │   │           │   │   ├── callbacks.cpython-37.pyc
# │   │           │   │   ├── html5lib_shim.cpython-37.pyc
# │   │           │   │   ├── linkifier.cpython-37.pyc
# │   │           │   │   ├── sanitizer.cpython-37.pyc
# │   │           │   │   └── utils.cpython-37.pyc
# │   │           │   ├── _vendor
# │   │           │   │   ├── README.rst
# │   │           │   │   ├── __init__.py
# │   │           │   │   ├── __pycache__
# │   │           │   │   │   └── __init__.cpython-37.pyc
# │   │           │   │   ├── html5lib
# │   │           │   │   │   ├── __init__.py
# │   │           │   │   │   ├── __pycache__
# │   │           │   │   │   │   ├── __init__.cpython-37.pyc
# │   │           │   │   │   │   ├── _ihatexml.cpython-37.pyc
# │   │           │   │   │   │   ├── _inputstream.cpython-37.pyc
# │   │           │   │   │   │   ├── _tokenizer.cpython-37.pyc
# │   │           │   │   │   │   ├── _utils.cpython-37.pyc
# │   │           │   │   │   │   ├── constants.cpython-37.pyc
# │   │           │   │   │   │   ├── html5parser.cpython-37.pyc
# │   │           │   │   │   │   └── serializer.cpython-37.pyc
# │   │           │   │   │   ├── _ihatexml.py
# │   │           │   │   │   ├── _inputstream.py
# │   │           │   │   │   ├── _tokenizer.py
# │   │           │   │   │   ├── _trie
# │   │           │   │   │   │   ├── __init__.py
# │   │           │   │   │   │   ├── __pycache__
# │   │           │   │   │   │   │   ├── __init__.cpython-37.pyc
# │   │           │   │   │   │   │   ├── _base.cpython-37.pyc
# │   │           │   │   │   │   │   ├── datrie.cpython-37.pyc
# │   │           │   │   │   │   │   └── py.cpython-37.pyc
# │   │           │   │   │   │   ├── _base.py
# │   │           │   │   │   │   ├── datrie.py
# │   │           │   │   │   │   └── py.py
# │   │           │   │   │   ├── _utils.py
# │   │           │   │   │   ├── constants.py
# │   │           │   │   │   ├── filters
# │   │           │   │   │   │   ├── __init__.py
# │   │           │   │   │   │   ├── __pycache__
# │   │           │   │   │   │   │   ├── __init__.cpython-37.pyc
# │   │           │   │   │   │   │   ├── alphabeticalattributes.cpython-37.pyc
# │   │           │   │   │   │   │   ├── base.cpython-37.pyc
# │   │           │   │   │   │   │   ├── inject_meta_charset.cpython-37.pyc
# │   │           │   │   │   │   │   ├── lint.cpython-37.pyc
# │   │           │   │   │   │   │   ├── optionaltags.cpython-37.pyc
# │   │           │   │   │   │   │   ├── sanitizer.cpython-37.pyc
# │   │           │   │   │   │   │   └── whitespace.cpython-37.pyc
# │   │           │   │   │   │   ├── alphabeticalattributes.py
# │   │           │   │   │   │   ├── base.py
# │   │           │   │   │   │   ├── inject_meta_charset.py
# │   │           │   │   │   │   ├── lint.py
# │   │           │   │   │   │   ├── optionaltags.py
# │   │           │   │   │   │   ├── sanitizer.py
# │   │           │   │   │   │   └── whitespace.py
# │   │           │   │   │   ├── html5parser.py
# │   │           │   │   │   ├── serializer.py
# │   │           │   │   │   ├── treeadapters
# │   │           │   │   │   │   ├── __init__.py
# │   │           │   │   │   │   ├── __pycache__
# │   │           │   │   │   │   │   ├── __init__.cpython-37.pyc
# │   │           │   │   │   │   │   ├── genshi.cpython-37.pyc
# │   │           │   │   │   │   │   └── sax.cpython-37.pyc
# │   │           │   │   │   │   ├── genshi.py
# │   │           │   │   │   │   └── sax.py
# │   │           │   │   │   ├── treebuilders
# │   │           │   │   │   │   ├── __init__.py
# │   │           │   │   │   │   ├── __pycache__
# │   │           │   │   │   │   │   ├── __init__.cpython-37.pyc
# │   │           │   │   │   │   │   ├── base.cpython-37.pyc
# │   │           │   │   │   │   │   ├── dom.cpython-37.pyc
# │   │           │   │   │   │   │   ├── etree.cpython-37.pyc
# │   │           │   │   │   │   │   └── etree_lxml.cpython-37.pyc
# │   │           │   │   │   │   ├── base.py
# │   │           │   │   │   │   ├── dom.py
# │   │           │   │   │   │   ├── etree.py
# │   │           │   │   │   │   └── etree_lxml.py
# │   │           │   │   │   └── treewalkers
# │   │           │   │   │       ├── __init__.py
# │   │           │   │   │       ├── __pycache__
# │   │           │   │   │       │   ├── __init__.cpython-37.pyc
# │   │           │   │   │       │   ├── base.cpython-37.pyc
# │   │           │   │   │       │   ├── dom.cpython-37.pyc
# │   │           │   │   │       │   ├── etree.cpython-37.pyc
# │   │           │   │   │       │   ├── etree_lxml.cpython-37.pyc
# │   │           │   │   │       │   └── genshi.cpython-37.pyc
# │   │           │   │   │       ├── base.py
# │   │           │   │   │       ├── dom.py
# │   │           │   │   │       ├── etree.py
# │   │           │   │   │       ├── etree_lxml.py
# │   │           │   │   │       └── genshi.py
# │   │           │   │   ├── html5lib-1.0.1.dist-info
# │   │           │   │   │   ├── DESCRIPTION.rst
# │   │           │   │   │   ├── INSTALLER
# │   │           │   │   │   ├── LICENSE.txt
# │   │           │   │   │   ├── METADATA
# │   │           │   │   │   ├── RECORD
# │   │           │   │   │   ├── WHEEL
# │   │           │   │   │   ├── metadata.json
# │   │           │   │   │   └── top_level.txt
# │   │           │   │   ├── pip_install_vendor.sh
# │   │           │   │   └── vendor.txt
# │   │           │   ├── callbacks.py
# │   │           │   ├── html5lib_shim.py
# │   │           │   ├── linkifier.py
# │   │           │   ├── sanitizer.py
# │   │           │   └── utils.py
# │   │           ├── bleach-3.1.4.dist-info
# │   │           │   ├── INSTALLER
# │   │           │   ├── LICENSE
# │   │           │   ├── METADATA
# │   │           │   ├── RECORD
# │   │           │   ├── WHEEL
# │   │           │   └── top_level.txt
# │   │           ├── cycler-0.10.0.dist-info
# │   │           │   ├── DESCRIPTION.rst
# │   │           │   ├── INSTALLER
# │   │           │   ├── METADATA
# │   │           │   ├── RECORD
# │   │           │   ├── WHEEL
# │   │           │   ├── metadata.json
# │   │           │   └── top_level.txt
# │   │           ├── cycler.py
# │   │           ├── dateutil
# │   │           │   ├── __init__.py
# │   │           │   ├── __pycache__
# │   │           │   │   ├── __init__.cpython-37.pyc
# │   │           │   │   ├── _common.cpython-37.pyc
# │   │           │   │   ├── _version.cpython-37.pyc
# │   │           │   │   ├── easter.cpython-37.pyc
# │   │           │   │   ├── relativedelta.cpython-37.pyc
# │   │           │   │   ├── rrule.cpython-37.pyc
# │   │           │   │   ├── tzwin.cpython-37.pyc
# │   │           │   │   └── utils.cpython-37.pyc
# │   │           │   ├── _common.py
# │   │           │   ├── _version.py
# │   │           │   ├── easter.py
# │   │           │   ├── parser
# │   │           │   │   ├── __init__.py
# │   │           │   │   ├── __pycache__
# │   │           │   │   │   ├── __init__.cpython-37.pyc
# │   │           │   │   │   ├── _parser.cpython-37.pyc
# │   │           │   │   │   └── isoparser.cpython-37.pyc
# │   │           │   │   ├── _parser.py
# │   │           │   │   └── isoparser.py
# │   │           │   ├── relativedelta.py
# │   │           │   ├── rrule.py
# │   │           │   ├── tz
# │   │           │   │   ├── __init__.py
# │   │           │   │   ├── __pycache__
# │   │           │   │   │   ├── __init__.cpython-37.pyc
# │   │           │   │   │   ├── _common.cpython-37.pyc
# │   │           │   │   │   ├── _factories.cpython-37.pyc
# │   │           │   │   │   ├── tz.cpython-37.pyc
# │   │           │   │   │   └── win.cpython-37.pyc
# │   │           │   │   ├── _common.py
# │   │           │   │   ├── _factories.py
# │   │           │   │   ├── tz.py
# │   │           │   │   └── win.py
# │   │           │   ├── tzwin.py
# │   │           │   ├── utils.py
# │   │           │   └── zoneinfo
# │   │           │       ├── __init__.py
# │   │           │       ├── __pycache__
# │   │           │       │   ├── __init__.cpython-37.pyc
# │   │           │       │   └── rebuild.cpython-37.pyc
# │   │           │       ├── dateutil-zoneinfo.tar.gz
# │   │           │       └── rebuild.py
# │   │           ├── decorator-4.4.2.dist-info
# │   │           │   ├── INSTALLER
# │   │           │   ├── LICENSE.txt
# │   │           │   ├── METADATA
# │   │           │   ├── RECORD
# ...
# │   │           │       ├── extension.js
# │   │           │       └── extension.js.map
# │   │           ├── widgetsnbextension-3.5.1.dist-info
# │   │           │   ├── INSTALLER
# │   │           │   ├── LICENSE
# │   │           │   ├── METADATA
# │   │           │   ├── RECORD
# │   │           │   ├── WHEEL
# │   │           │   └── top_level.txt
# │   │           ├── zipp-3.1.0.dist-info
# │   │           │   ├── INSTALLER
# │   │           │   ├── LICENSE
# │   │           │   ├── METADATA
# │   │           │   ├── RECORD
# │   │           │   ├── WHEEL
# │   │           │   └── top_level.txt
# │   │           ├── zipp.py
# │   │           └── zmq
# │   │               ├── __init__.pxd
# │   │               ├── __init__.py
# │   │               ├── __pycache__
# │   │               │   ├── __init__.cpython-37.pyc
# │   │               │   ├── _future.cpython-37.pyc
# │   │               │   ├── decorators.cpython-37.pyc
# │   │               │   └── error.cpython-37.pyc
# │   │               ├── _future.py
# │   │               ├── asyncio
# │   │               │   ├── __init__.py
# │   │               │   └── __pycache__
# │   │               │       └── __init__.cpython-37.pyc
# │   │               ├── auth
# │   │               │   ├── __init__.py
# │   │               │   ├── __pycache__
# │   │               │   │   ├── __init__.cpython-37.pyc
# │   │               │   │   ├── base.cpython-37.pyc
# │   │               │   │   ├── certs.cpython-37.pyc
# │   │               │   │   ├── ioloop.cpython-37.pyc
# │   │               │   │   └── thread.cpython-37.pyc
# │   │               │   ├── asyncio
# │   │               │   │   ├── __init__.py
# │   │               │   │   └── __pycache__
# │   │               │   │       └── __init__.cpython-37.pyc
# │   │               │   ├── base.py
# │   │               │   ├── certs.py
# │   │               │   ├── ioloop.py
# │   │               │   └── thread.py
# │   │               ├── backend
# │   │               │   ├── __init__.py
# │   │               │   ├── __pycache__
# │   │               │   │   ├── __init__.cpython-37.pyc
# │   │               │   │   └── select.cpython-37.pyc
# │   │               │   ├── cffi
# │   │               │   │   ├── __init__.py
# │   │               │   │   ├── __pycache__
# │   │               │   │   │   ├── __init__.cpython-37.pyc
# │   │               │   │   │   ├── _cffi.cpython-37.pyc
# │   │               │   │   │   ├── _poll.cpython-37.pyc
# │   │               │   │   │   ├── constants.cpython-37.pyc
# │   │               │   │   │   ├── context.cpython-37.pyc
# │   │               │   │   │   ├── devices.cpython-37.pyc
# │   │               │   │   │   ├── error.cpython-37.pyc
# │   │               │   │   │   ├── message.cpython-37.pyc
# │   │               │   │   │   ├── socket.cpython-37.pyc
# │   │               │   │   │   └── utils.cpython-37.pyc
# │   │               │   │   ├── _cdefs.h
# │   │               │   │   ├── _cffi.py
# │   │               │   │   ├── _poll.py
# │   │               │   │   ├── _verify.c
# │   │               │   │   ├── constants.py
# │   │               │   │   ├── context.py
# │   │               │   │   ├── devices.py
# │   │               │   │   ├── error.py
# │   │               │   │   ├── message.py
# │   │               │   │   ├── socket.py
# │   │               │   │   └── utils.py
# │   │               │   ├── cython
# │   │               │   │   ├── __init__.pxd
# │   │               │   │   ├── __init__.py
# │   │               │   │   ├── __pycache__
# │   │               │   │   │   └── __init__.cpython-37.pyc
# │   │               │   │   ├── _device.cpython-37m-darwin.so
# │   │               │   │   ├── _poll.cpython-37m-darwin.so
# │   │               │   │   ├── _proxy_steerable.cpython-37m-darwin.so
# │   │               │   │   ├── _version.cpython-37m-darwin.so
# │   │               │   │   ├── checkrc.pxd
# │   │               │   │   ├── constant_enums.pxi
# │   │               │   │   ├── constants.cpython-37m-darwin.so
# │   │               │   │   ├── constants.pxi
# │   │               │   │   ├── context.cpython-37m-darwin.so
# │   │               │   │   ├── context.pxd
# │   │               │   │   ├── error.cpython-37m-darwin.so
# │   │               │   │   ├── libzmq.pxd
# │   │               │   │   ├── message.cpython-37m-darwin.so
# │   │               │   │   ├── message.pxd
# │   │               │   │   ├── socket.cpython-37m-darwin.so
# │   │               │   │   ├── socket.pxd
# │   │               │   │   └── utils.cpython-37m-darwin.so
# │   │               │   └── select.py
# │   │               ├── decorators.py
# │   │               ├── devices
# │   │               │   ├── __init__.py
# │   │               │   ├── __pycache__
# │   │               │   │   ├── __init__.cpython-37.pyc
# │   │               │   │   ├── basedevice.cpython-37.pyc
# │   │               │   │   ├── monitoredqueue.cpython-37.pyc
# │   │               │   │   ├── monitoredqueuedevice.cpython-37.pyc
# │   │               │   │   ├── proxydevice.cpython-37.pyc
# │   │               │   │   └── proxysteerabledevice.cpython-37.pyc
# │   │               │   ├── basedevice.py
# │   │               │   ├── monitoredqueue.cpython-37m-darwin.so
# │   │               │   ├── monitoredqueue.pxd
# │   │               │   ├── monitoredqueue.py
# │   │               │   ├── monitoredqueuedevice.py
# │   │               │   ├── proxydevice.py
# │   │               │   └── proxysteerabledevice.py
# │   │               ├── error.py
# │   │               ├── eventloop
# │   │               │   ├── __init__.py
# │   │               │   ├── __pycache__
# │   │               │   │   ├── __init__.cpython-37.pyc
# │   │               │   │   ├── _deprecated.cpython-37.pyc
# │   │               │   │   ├── future.cpython-37.pyc
# │   │               │   │   ├── ioloop.cpython-37.pyc
# │   │               │   │   └── zmqstream.cpython-37.pyc
# │   │               │   ├── _deprecated.py
# │   │               │   ├── future.py
# │   │               │   ├── ioloop.py
# │   │               │   ├── minitornado
# │   │               │   │   ├── __init__.py
# │   │               │   │   ├── __pycache__
# │   │               │   │   │   ├── __init__.cpython-37.pyc
# │   │               │   │   │   ├── concurrent.cpython-37.pyc
# │   │               │   │   │   ├── ioloop.cpython-37.pyc
# │   │               │   │   │   ├── log.cpython-37.pyc
# │   │               │   │   │   ├── stack_context.cpython-37.pyc
# │   │               │   │   │   └── util.cpython-37.pyc
# │   │               │   │   ├── concurrent.py
# │   │               │   │   ├── ioloop.py
# │   │               │   │   ├── log.py
# │   │               │   │   ├── platform
# │   │               │   │   │   ├── __init__.py
# │   │               │   │   │   ├── __pycache__
# │   │               │   │   │   │   ├── __init__.cpython-37.pyc
# │   │               │   │   │   │   ├── auto.cpython-37.pyc
# │   │               │   │   │   │   ├── common.cpython-37.pyc
# │   │               │   │   │   │   ├── interface.cpython-37.pyc
# │   │               │   │   │   │   ├── posix.cpython-37.pyc
# │   │               │   │   │   │   └── windows.cpython-37.pyc
# │   │               │   │   │   ├── auto.py
# │   │               │   │   │   ├── common.py
# │   │               │   │   │   ├── interface.py
# │   │               │   │   │   ├── posix.py
# │   │               │   │   │   └── windows.py
# │   │               │   │   ├── stack_context.py
# │   │               │   │   └── util.py
# │   │               │   └── zmqstream.py
# │   │               ├── green
# │   │               │   ├── __init__.py
# │   │               │   ├── __pycache__
# │   │               │   │   ├── __init__.cpython-37.pyc
# │   │               │   │   ├── core.cpython-37.pyc
# │   │               │   │   ├── device.cpython-37.pyc
# │   │               │   │   └── poll.cpython-37.pyc
# │   │               │   ├── core.py
# │   │               │   ├── device.py
# │   │               │   ├── eventloop
# │   │               │   │   ├── __init__.py
# │   │               │   │   ├── __pycache__
# │   │               │   │   │   ├── __init__.cpython-37.pyc
# │   │               │   │   │   ├── ioloop.cpython-37.pyc
# │   │               │   │   │   └── zmqstream.cpython-37.pyc
# │   │               │   │   ├── ioloop.py
# │   │               │   │   └── zmqstream.py
# │   │               │   └── poll.py
# │   │               ├── include
# │   │               │   ├── zmq.h
# │   │               │   └── zmq_utils.h
# │   │               ├── libzmq.cpython-37m-darwin.so
# │   │               ├── log
# │   │               │   ├── __init__.py
# │   │               │   ├── __main__.py
# │   │               │   ├── __pycache__
# │   │               │   │   ├── __init__.cpython-37.pyc
# │   │               │   │   ├── __main__.cpython-37.pyc
# │   │               │   │   └── handlers.cpython-37.pyc
# │   │               │   └── handlers.py
# │   │               ├── ssh
# │   │               │   ├── __init__.py
# │   │               │   ├── __pycache__
# │   │               │   │   ├── __init__.cpython-37.pyc
# │   │               │   │   ├── forward.cpython-37.pyc
# │   │               │   │   └── tunnel.cpython-37.pyc
# │   │               │   ├── forward.py
# │   │               │   └── tunnel.py
# │   │               ├── sugar
# │   │               │   ├── __init__.py
# │   │               │   ├── __pycache__
# │   │               │   │   ├── __init__.cpython-37.pyc
# │   │               │   │   ├── attrsettr.cpython-37.pyc
# │   │               │   │   ├── constants.cpython-37.pyc
# │   │               │   │   ├── context.cpython-37.pyc
# │   │               │   │   ├── frame.cpython-37.pyc
# │   │               │   │   ├── poll.cpython-37.pyc
# │   │               │   │   ├── socket.cpython-37.pyc
# │   │               │   │   ├── stopwatch.cpython-37.pyc
# │   │               │   │   ├── tracker.cpython-37.pyc
# │   │               │   │   └── version.cpython-37.pyc
# │   │               │   ├── attrsettr.py
# │   │               │   ├── constants.py
# │   │               │   ├── context.py
# │   │               │   ├── frame.py
# │   │               │   ├── poll.py
# │   │               │   ├── socket.py
# │   │               │   ├── stopwatch.py
# │   │               │   ├── tracker.py
# │   │               │   └── version.py
# │   │               ├── tests
# │   │               │   ├── __init__.py
# │   │               │   ├── __pycache__
# │   │               │   │   ├── __init__.cpython-37.pyc
# │   │               │   │   ├── conftest.cpython-37.pyc
# │   │               │   │   ├── test_auth.cpython-37.pyc
# │   │               │   │   ├── test_cffi_backend.cpython-37.pyc
# │   │               │   │   ├── test_constants.cpython-37.pyc
# │   │               │   │   ├── test_context.cpython-37.pyc
# │   │               │   │   ├── test_cython.cpython-37.pyc
# │   │               │   │   ├── test_decorators.cpython-37.pyc
# │   │               │   │   ├── test_device.cpython-37.pyc
# │   │               │   │   ├── test_draft.cpython-37.pyc
# │   │               │   │   ├── test_error.cpython-37.pyc
# │   │               │   │   ├── test_etc.cpython-37.pyc
# │   │               │   │   ├── test_future.cpython-37.pyc
# │   │               │   │   ├── test_imports.cpython-37.pyc
# │   │               │   │   ├── test_includes.cpython-37.pyc
# │   │               │   │   ├── test_ioloop.cpython-37.pyc
# │   │               │   │   ├── test_log.cpython-37.pyc
# │   │               │   │   ├── test_message.cpython-37.pyc
# │   │               │   │   ├── test_monitor.cpython-37.pyc
# │   │               │   │   ├── test_monqueue.cpython-37.pyc
# │   │               │   │   ├── test_multipart.cpython-37.pyc
# │   │               │   │   ├── test_pair.cpython-37.pyc
# │   │               │   │   ├── test_poll.cpython-37.pyc
# │   │               │   │   ├── test_proxy_steerable.cpython-37.pyc
# │   │               │   │   ├── test_pubsub.cpython-37.pyc
# │   │               │   │   ├── test_reqrep.cpython-37.pyc
# │   │               │   │   ├── test_retry_eintr.cpython-37.pyc
# │   │               │   │   ├── test_security.cpython-37.pyc
# │   │               │   │   ├── test_socket.cpython-37.pyc
# │   │               │   │   ├── test_ssh.cpython-37.pyc
# │   │               │   │   ├── test_version.cpython-37.pyc
# │   │               │   │   ├── test_win32_shim.cpython-37.pyc
# │   │               │   │   ├── test_z85.cpython-37.pyc
# │   │               │   │   └── test_zmqstream.cpython-37.pyc
# │   │               │   ├── asyncio
# │   │               │   │   ├── __init__.py
# │   │               │   │   ├── __pycache__
# │   │               │   │   │   ├── __init__.cpython-37.pyc
# │   │               │   │   │   ├── _test_asyncio.cpython-37.pyc
# │   │               │   │   │   └── test_asyncio.cpython-37.pyc
# │   │               │   │   ├── _test_asyncio.py
# │   │               │   │   └── test_asyncio.py
# │   │               │   ├── conftest.py
# │   │               │   ├── test_auth.py
# │   │               │   ├── test_cffi_backend.py
# │   │               │   ├── test_constants.py
# │   │               │   ├── test_context.py
# │   │               │   ├── test_cython.py
# │   │               │   ├── test_decorators.py
# │   │               │   ├── test_device.py
# │   │               │   ├── test_draft.py
# │   │               │   ├── test_error.py
# │   │               │   ├── test_etc.py
# │   │               │   ├── test_future.py
# │   │               │   ├── test_imports.py
# │   │               │   ├── test_includes.py
# │   │               │   ├── test_ioloop.py
# │   │               │   ├── test_log.py
# │   │               │   ├── test_message.py
# │   │               │   ├── test_monitor.py
# │   │               │   ├── test_monqueue.py
# │   │               │   ├── test_multipart.py
# │   │               │   ├── test_pair.py
# │   │               │   ├── test_poll.py
# │   │               │   ├── test_proxy_steerable.py
# │   │               │   ├── test_pubsub.py
# │   │               │   ├── test_reqrep.py
# │   │               │   ├── test_retry_eintr.py
# │   │               │   ├── test_security.py
# │   │               │   ├── test_socket.py
# │   │               │   ├── test_ssh.py
# │   │               │   ├── test_version.py
# │   │               │   ├── test_win32_shim.py
# │   │               │   ├── test_z85.py
# │   │               │   └── test_zmqstream.py
# │   │               └── utils
# │   │                   ├── __init__.py
# │   │                   ├── __pycache__
# │   │                   │   ├── __init__.cpython-37.pyc
# │   │                   │   ├── constant_names.cpython-37.pyc
# │   │                   │   ├── garbage.cpython-37.pyc
# │   │                   │   ├── interop.cpython-37.pyc
# │   │                   │   ├── jsonapi.cpython-37.pyc
# │   │                   │   ├── monitor.cpython-37.pyc
# │   │                   │   ├── sixcerpt.cpython-37.pyc
# │   │                   │   ├── strtypes.cpython-37.pyc
# │   │                   │   ├── win32.cpython-37.pyc
# │   │                   │   └── z85.cpython-37.pyc
# │   │                   ├── buffers.pxd
# │   │                   ├── compiler.json
# │   │                   ├── config.json
# │   │                   ├── constant_names.py
# │   │                   ├── garbage.py
# │   │                   ├── getpid_compat.h
# │   │                   ├── interop.py
# │   │                   ├── ipcmaxlen.h
# │   │                   ├── jsonapi.py
# │   │                   ├── monitor.py
# │   │                   ├── mutex.h
# │   │                   ├── pyversion_compat.h
# │   │                   ├── sixcerpt.py
# │   │                   ├── strtypes.py
# │   │                   ├── win32.py
# │   │                   ├── z85.py
# │   │                   ├── zmq_compat.h
# │   │                   └── zmq_constants.h
# │   ├── pyvenv.cfg
# │   └── share
# │       ├── jupyter
# │       │   ├── kernels
# │       │   │   └── python3
# │       │   │       ├── kernel.json
# │       │   │       ├── logo-32x32.png
# │       │   │       └── logo-64x64.png
# │       │   └── nbextensions
# │       │       └── jupyter-js-widgets
# │       │           ├── extension.js
# │       │           └── extension.js.map
# │       └── man
# │           └── man1
# │               └── ipython.1.gz
# ├── workshop_data_mining.ipynb
# └── workshop_data_mining_script.pdf
#
# 1974 directories, 14964 files

# %%
#!pip3 freeze > requirements.txt

# %% [markdown]
# ## Installieren der benötigten Python-Module

# %%
#!pip3 install numpy matplotlib pandas scikit-learn jupyter

# %%
#!pip3 install --upgrade -r requirements.txt

# %%
# !pipenv install scikit-learn
# Out:
# Warning: the environment variable LANG is not set!
# We recommend setting this in ~/.profile (or equivalent) for proper expected behavior.
# Creating a virtualenv for this project…
# Pipfile: /Users/tinvotan/Projects/dhbw_data_mining/Pipfile
# Using /Users/tinvotan/.virtualenvs/dhbw_data_mining-T-rrwOFW/bin/python3.8 (3.8.3) to create virtualenv…
# ⠧ Creating virtual environment...created virtual environment CPython3.8.3.final.0-64 in 470ms
#   creator CPython3Posix(dest=/Users/tinvotan/.virtualenvs/dhbw_data_mining-BQYErwnp, clear=False, global=False)
#   seeder FromAppData(download=False, pip=latest, setuptools=latest, wheel=latest, via=copy, app_data_dir=/Users/tinvotan/Library/Application Support/virtualenv/seed-app-data/v1.0.1)
#   activators BashActivator,CShellActivator,FishActivator,PowerShellActivator,PythonActivator,XonshActivator
#
# ✔ Successfully created virtual environment!
# Virtualenv location: /Users/tinvotan/.virtualenvs/dhbw_data_mining-BQYErwnp
# Installing scikit-learn…
# Adding scikit-learn to Pipfile's [packages]…
# ✔ Installation Succeeded
# Installing dependencies from Pipfile.lock (0e965f)…
#   🐍   ▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉ 56/56 — 00:00:40mmmmmmmmmmmmmmmmmmmmmmmmmmmmmmm

# %%
import sklearn

# %%
import numpy

# %%
numpy.__version__
# Out:
# '1.19.0'

# %%
sklearn.__version__
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-2c9e2e7ba1f4> in <module>
# ----> 1 sklearn.__version__
#
# NameError: name 'sklearn' is not defined
